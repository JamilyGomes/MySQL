# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv("/kaggle/input/nba-players-data/all_seasons.csv")

df.head()

df1= df.loc[0:11145, ["player_weight"]]
df2= df.loc[0:11145,["player_height"]]

plt.xlabel('peso')
plt.ylabel('Altura')
plt.title('Peso e Altura')

plt.scatter(df1, df2)
plt.show()
